# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\Administrator\\Desktop\\Python folder\\cars.csv")
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# #### Check Duplicate Records

# %%
df.shape
# Out:
# (11914, 16)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (715, 16)

# %% [markdown]
# #### Drop Duplicate Records

# %%
df = df.drop_duplicates()
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### Check missing or null values

# %%
print(df.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# #### Drop missing or null values

# %%
df = df.dropna()
df.count()
# Out:
# Make                 7735
# Model                7735
# Year                 7735
# Engine Fuel Type     7735
# Engine HP            7735
# Engine Cylinders     7735
# Transmission Type    7735
# Driven_Wheels        7735
# Number of Doors      7735
# Market Category      7735
# Vehicle Size         7735
# Vehicle Style        7735
# highway MPG          7735
# city mpg             7735
# Popularity           7735
# MSRP                 7735
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# #### Show top 10 average MSRP (Price) per car brand (rounded figure)?

# %%
top_10_car_brand_price = (df.groupby("Make")["MSRP"].mean().round(0).sort_values(ascending=False).head(10).reset_index())
top_10_car_brand_price
# Out:
#            Make       MSRP
# 0       Bugatti  1757224.0
# 1       Maybach   546222.0
# 2   Rolls-Royce   351131.0
# 3   Lamborghini   331567.0
# 4       Bentley   247169.0
# 5       McLaren   239805.0
# 6       Ferrari   237384.0
# 7        Spyker   214990.0
# 8  Aston Martin   198123.0
# 9      Maserati   113684.0

# %% [markdown]
# #### Show the average MSRP (price) per years (rounded figure)?

# %%
avg_price_per_year = (df.groupby("Year")["MSRP"].mean().round(0).reset_index())
avg_price_per_year
# Out:
#     Year     MSRP
# 0   1990   2073.0
# 1   1991   2223.0
# 2   1992   2192.0
# 3   1993   2401.0
# 4   1994   2726.0
# 5   1995   3270.0
# 6   1996   3140.0
# 7   1997   4524.0
# 8   1998   4434.0
# 9   1999   3612.0
# 10  2000   3913.0
# 11  2001  73833.0
# 12  2002  55704.0
# 13  2003  68312.0
# 14  2004  55908.0
# 15  2005  53724.0
# 16  2006  39001.0
# 17  2007  41173.0
# 18  2008  80462.0
# 19  2009  59193.0
# 20  2010  60152.0
# 21  2011  65663.0
# 22  2012  71837.0
# 23  2013  55201.0
# 24  2014  71196.0
# 25  2015  52613.0
# 26  2016  52580.0
# 27  2017  45333.0

# %% [markdown]
# #### Show average Engine HP (power) rounded figure and MPG (efficiency) rounded figure per year?
#
# Hint: Average of (city mpg + highway MPG)

# %%
df["Avg_MPG"] = (df["city mpg"] + df["highway MPG"]) / 2
df["Avg_MPG"]
# Out:
# 0        22.5
# 1        23.5
# 2        24.0
# 3        23.0
# 4        23.0
#          ...
# 11909    19.5
# 11910    19.5
# 11911    19.5
# 11912    19.5
# 11913    21.5
# Name: Avg_MPG, Length: 7735, dtype: float64

# %%
df.groupby("Year")[["Engine HP", "Avg_MPG"]].mean().round(0)
# Out:
#       Engine HP  Avg_MPG
# Year
# 1990      154.0     21.0
# 1991      163.0     21.0
# 1992      155.0     22.0
# 1993      174.0     21.0
# 1994      167.0     21.0
# 1995      203.0     20.0
# 1996      201.0     21.0
# 1997      200.0     21.0
# 1998      224.0     20.0
# 1999      199.0     21.0
# 2000      202.0     21.0
# 2001      243.0     20.0
# 2002      244.0     19.0
# 2003      258.0     19.0
# 2004      260.0     19.0
# 2005      255.0     20.0
# 2006      248.0     20.0
# 2007      274.0     18.0
# 2008      298.0     19.0
# 2009      268.0     20.0
# 2010      269.0     20.0
# 2011      280.0     22.0
# 2012      293.0     22.0
# 2013      290.0     23.0
# 2014      311.0     23.0
# 2015      288.0     24.0
# 2016      290.0     24.0
# 2017      285.0     25.0

# %%
avg_engineHP_and_MPG_per_year = (df.groupby("Year", as_index=False).agg(Avg_Engine_HP = ("Engine HP", "mean"),Avg_MPG= ("Avg_MPG", "mean")).round(0).sort_values("Year"))
avg_engineHP_and_MPG_per_year
# Out:
#     Year  Avg_Engine_HP  Avg_MPG
# 0   1990          154.0     21.0
# 1   1991          163.0     21.0
# 2   1992          155.0     22.0
# 3   1993          174.0     21.0
# 4   1994          167.0     21.0
# 5   1995          203.0     20.0
# 6   1996          201.0     21.0
# 7   1997          200.0     21.0
# 8   1998          224.0     20.0
# 9   1999          199.0     21.0
# 10  2000          202.0     21.0
# 11  2001          243.0     20.0
# 12  2002          244.0     19.0
# 13  2003          258.0     19.0
# 14  2004          260.0     19.0
# 15  2005          255.0     20.0
# 16  2006          248.0     20.0
# 17  2007          274.0     18.0
# 18  2008          298.0     19.0
# 19  2009          268.0     20.0
# 20  2010          269.0     20.0
# 21  2011          280.0     22.0
# 22  2012          293.0     22.0
# 23  2013          290.0     23.0
# 24  2014          311.0     23.0
# 25  2015          288.0     24.0
# 26  2016          290.0     24.0
# ...

# %% [markdown]
# #### What percentage of cars are Compact, Midsize, or Large?

# %%
df["Vehicle Size"].unique()
# Out:
# array(['Compact', 'Midsize', 'Large'], dtype=object)

# %%
df["Vehicle Size"].value_counts(normalize=True).mul(100).round(0)
# Out:
# Vehicle Size
# Midsize    39.0
# Compact    37.0
# Large      24.0
# Name: proportion, dtype: float64

# %%
size_df = (df["Vehicle Size"].value_counts(normalize=True).mul(100).round(0).reset_index().rename(columns={"index": "Vehicle Size", "Vehicle Size": "Percentage"}))
size_df
# Out:
#   Percentage  proportion
# 0    Midsize        39.0
# 1    Compact        37.0
# 2      Large        24.0

# %% [markdown]
# #### Which vehicle styles are the most sold (most common) in the dataset?

# %%
most_common_vehicle_styles = df["Vehicle Style"].mode()
most_common_vehicle_styles
# Out:
# 0    4dr SUV
# Name: Vehicle Style, dtype: object

# %%
counts = df["Vehicle Style"].value_counts()
max_count = counts.max()
most_common_df = counts[counts == max_count].reset_index()
most_common_df.columns = ["Vehicle Style", "Count"]
most_common_df
# Out:
#   Vehicle Style  Count
# 0       4dr SUV   2053

# %% [markdown]
# #### Which car brands have the most vehicles priced at $40,000 or more and with a popularity score of at least 1000?

# %%
filtered = df[(df["MSRP"] >= 40000) & (df["Popularity"] >= 1000)]
top_brands = (filtered["Make"].value_counts().reset_index().rename(columns={"index": "Make", "Make": "Count"}))
top_brands
# Out:
#           Count  count
# 0      Cadillac    354
# 1           BMW    269
# 2          Audi    224
# 3     Chevrolet    171
# 4       Porsche    123
# 5          Ford    105
# 6        Nissan     69
# 7       Ferrari     68
# 8   Lamborghini     52
# 9        Toyota     50
# 10        Dodge     49
# 11          Kia     16
# 12      Hyundai     13
# 13     Chrysler     12
# 14        Honda      8

# %% [markdown]
# #### Check if there are outliers in Engine HP show boxplot

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(df["Engine HP"].dropna())
plt.title("Boxplot of Engine HP")
plt.xlabel("Engine HP")
plt.show()

# %% [markdown]
# #### Check if there are outliers in Engine Cylinder show boxplot

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(df["Engine Cylinders"].dropna())
plt.title("Boxplot of Engine Cylinders")
plt.xlabel("Engine Cylinders")
plt.show()

# %% [markdown]
# #### Find upper bound, lower bound, number of outliers in Engine HP

# %%
Q1 = df["Engine HP"].quantile(0.25)
Q3 = df["Engine HP"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["Engine HP"] < lower_bound) | (df["Engine HP"] > upper_bound)]

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print("Number of Outliers:", outliers.shape[0])
# Out:
# Lower Bound: -2.5
# Upper Bound: 521.5
# Number of Outliers: 381

# %% [markdown]
# #### Fill missing values in Number of Doors column with median value then check if values are filled

# %%
df["Number of Doors"].fillna(df["Number of Doors"].median(), inplace=True)
print(df["Number of Doors"].isna().sum())
# Out:
# 0

# %%
median_doors = df["Number of Doors"].median()
df["Number of Doors"].fillna(median_doors, inplace=True)
missing_count = df["Number of Doors"].isna().sum()
print("Number of missing values in 'Number of Doors':", missing_count)
# Out:
# Number of missing values in 'Number of Doors': 0
